# %% [markdown]
# <a href="https://colab.research.google.com/github/medicalmom/M7/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
mv_data = pd.read_csv('https://data.cityofnewyork.us/resource/h9gi-nx95.csv?$limit=30000&borough=BROOKLYN&contributing_factor_vehicle_1=Driver%20Inexperience')

# %% [markdown]
# ### We import the data set from nypd motor vehicle crash and limit 30,000 rows and looking at the values containing Brooklyn (borough of occurance) and Driver Inexperience (for contributing factor vehicle 1) This will allow us to work with some of the dataset and look at crashes involving driver inexperience in the borough of Brooklyn.

# %% [markdown]
# ### Next, look at the number of rows and columns in the data set imported using shape command

# %%
mv_data.shape
# Out:
# (4682, 29)

# %% [markdown]
# ### We have 4,677 rows and 29 columns of data in the information imported. Let's put it into an array with headers for each column

# %%
mv_data.head()
# Out:
#                       date   time  ... vehicle_type_code_4  vehicle_type_code_5
# 0  2019-07-15T00:00:00.000  13:45  ...                 NaN                  NaN
# 1  2019-07-17T00:00:00.000   2:30  ...                 NaN                  NaN
# 2  2019-07-09T00:00:00.000  15:15  ...                 NaN                  NaN
# 3  2019-07-11T00:00:00.000   0:30  ...                 NaN                  NaN
# 4  2019-07-03T00:00:00.000   0:00  ...                 NaN                  NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Now we can find the unique types of vehicles involved in these crashes. Let's look at vehcile number one, the first vehicle impacting. This column value is vehicle_type_code1.

# %%
mv_data['vehicle_type_code1'].unique()
# Out:
# array(['Van', 'Station Wagon/Sport Utility Vehicle', nan, 'Sedan',
#        'Moped', 'Motorbike', 'Pick-up Truck', 'Garbage or Refuse', 'Taxi',
#        'Tractor Truck Gasoline', 'Motorcycle', 'Minicycle', 'TRUCK',
#        'usps', 'Box Truck', 'MOPD', 'Bus', 'tow t', 'MOPED',
#        'Tractor Truck Diesel', 'STREE', 'Motorscooter', 'Bike', 'E-Sco',
#        'Dump', 'E-Bik', 'DELIV', 'Chassis Cab', 'Ambulance', 'Trail',
#        'PASSENGER VEHICLE', 'Tanker', 'SPORT UTILITY / STATION WAGON',
#        'PICK-UP TRUCK', 'BICYCLE', 'MOTORCYCLE', 'TAXI', 'RESCU', 'CRANE',
#        'TRACK', 'PK', 'Flat Bed', 'CONV', 'BU', 'TK', 'VN', 'BULLD', 'FB',
#        'Ambul', 'NYPD', 'Convertible', 'motor', 'FDNY', 'Carry All',
#        'Tow Truck / Wrecker', '3-Door', 'FIRE', 'MS', 'GG', 'DS', 'AM',
#        'CB', 'TOW T', 'LL', 'TOW', 'DP', 'FORKL', 'BUS', 'OTHER',
#        'SMALL COM VEH(4 TIRES) ', 'LARGE COM VEH(6 OR MORE TIRES)',
#        'UNKNOWN', 'LIVERY VEHICLE', 'VAN', 'UTILI', 'SCOOTER',
#        '4 dr sedan', 'FIRE TRUCK', 'AMBULANCE'], dtype=object)

# %% [markdown]
# ### We can further narrow what we are looking at by selecting for vehicle types. We can look at Station Wagon/Sport Utility Vehicle and Sedan. So, in Brooklyn for inexperienced drivers, what can we see for this group driving Station Wagon/Sport Utility Vehicle versus driving a sedan.

# %%
mv_data['vehicle_type_code1'].value_counts()
# Out:
# PASSENGER VEHICLE                      2110
# SPORT UTILITY / STATION WAGON           859
# Sedan                                   547
# Station Wagon/Sport Utility Vehicle     377
# SMALL COM VEH(4 TIRES)                   75
# OTHER                                    70
# PICK-UP TRUCK                            68
# VAN                                      64
# TAXI                                     49
# LARGE COM VEH(6 OR MORE TIRES)           45
# UNKNOWN                                  43
# BUS                                      35
# Pick-up Truck                            35
# MOTORCYCLE                               35
# Taxi                                     31
# Box Truck                                30
# Bus                                      20
# Tractor Truck Diesel                     14
# Van                                      12
# LIVERY VEHICLE                           12
# BU                                        9
# TK                                        8
# Motorcycle                                8
# BICYCLE                                   7
# E-Sco                                     7
# Dump                                      6
# Bike                                      6
# AMBULANCE                                 6
# Motorscooter                              5
# SCOOTER                                   5
#                                        ...
# MOPD                                      1
# NYPD                                      1
# BULLD                                     1
# DELIV                                     1
# STREE                                     1
# RESCU                                     1
# FDNY                                      1
# usps                                      1
# LL                                        1
# CRANE                                     1
# TRACK                                     1
# Tow Truck / Wrecker                       1
# Ambul                                     1
# Trail                                     1
# FIRE                                      1
# TRUCK                                     1
# FORKL                                     1
# TOW T                                     1
# FIRE TRUCK                                1
# Garbage or Refuse                         1
# Convertible                               1
# AM                                        1
# 3-Door                                    1
# motor                                     1
# UTILI                                     1
# GG                                        1
# FB                                        1
# TOW                                       1
# tow t                                     1
# Minicycle                                 1
# Name: vehicle_type_code1, Length: 78, dtype: int64

# %% [markdown]
# ### So for Brooklyn and crashes due to inexperience driver, passenger vehicle (? what is this), sports utility/station wagon, sedan, and then station wagon/sport utility were the largest number of vehicles involved in the crashes. We could maybe combine sports utility/station wagon and station wagon/sport utility groups.

# %%
mv_data['vehicle_type_code1'] = mv_data['vehicle_type_code1'].str.replace('SPORT UTILITY / STATION WAGON', 'SUV')
mv_data['vehicle_type_code1'] = mv_data['vehicle_type_code1'].str.replace('Station Wagon/Sport Utility Vehicle', 'SUV')

# %% [markdown]
# ### We can plot using matplotlib to explore the data, looking for information and patterns.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

fig, ax = plt.subplots(figsize=(10,15))
ax.margins(0.05)
ax.plot(mv_data['contributing_factor_vehicle_1'],
       mv_data['number_of_pedestrians_injured'],
         marker='o',
       linestyle='',
       alpha=0.5)
plt.show()

# %% [markdown]
# ### within this plot we see driver inexperience had episdoes of 1,2, and 3 numbers of pedestrians injured.

# %% [markdown]
# ### Look at data for contributing factor vehicle1  and number of pedestrians injured in boxplot

# %%
mv_data.boxplot("contributing_factor_vehicle_1", by='number_of_pedestrians_injured')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-289852f5508d> in <module>()
# ----> 1 mv_data.boxplot("contributing_factor_vehicle_1", by='number_of_pedestrians_injured')
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2252     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2253                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2254                  return_type=return_type, **kwds)
#    2255     plt.draw_if_interactive()
#    2256     return ax
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2221                                          by=by, grid=grid, figsize=figsize,
#    2222                                          ax=ax, layout=layout,
# -> 2223                                          return_type=return_type)
#    2224     else:
#    2225         if return_type is None:
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#    2681         gp_col = grouped[col]
#    2682         keys, values = zip(*gp_col)
# -> 2683         re_plotf = plotf(keys, values, ax, **kwargs)
#    2684         ax.set_title(col)
#    2685         ax.set_xlabel(pprint_thing(by))
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in plot_group(keys, values, ax)
#    2189         keys = [pprint_thing(x) for x in keys]
#    2190         values = [np.asarray(remove_na_arraylike(v)) for v in values]
# -> 2191         bp = ax.boxplot(values, **kwds)
#    2192         if fontsize is not None:
#    2193             ax.tick_params(axis='both', labelsize=fontsize)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder)
#    3501
#    3502         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
# -> 3503                                        labels=labels, autorange=autorange)
#    3504         if notch is None:
#    3505             notch = rcParams['boxplot.notch']
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1213
#    1214         # arithmetic mean
# -> 1215         stats['mean'] = np.mean(x)
#    1216
#    1217         # medians and quartiles
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3118                           out=out, **kwargs)
#    3119
#    3120
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      85             ret = ret.dtype.type(ret / rcount)
#      86     else:
# ---> 87         ret = ret / rcount
#      88
#      89     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# ### Look at this same information with seaborn data visualization tool

# %%
import seaborn as sns
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 25))
sns.scatterplot(x="contributing_factor_vehicle_1", y="vehicle_type_code1", 
               hue="number_of_pedestrians_injured", linewidth=0, data=mv_data, ax=ax)

# %% [markdown]
# #### So, it looks like for this particular item, crashes with driver inexperience, most vehicles did not have pedestrian injuries. Livery vehicles had 1 pedestrian injury and "motor" (what is motor compared to motor vehicle, I'm not sure) had 1 pedestrian injury.
